# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import seaborn as sns

import missingno as msno 

import chart_studio.plotly as py
import cufflinks as cf
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
#Let's Load the data using panda library
df = pd.read_csv('kawasaki_disease_dataset.csv')

# %%
#Let's print the first 5 records of the data
df.head()
# Out:
#    Patient ID Date of Diagnosis  Age at Diagnosis  Gender         Ethnicity  \
# 0       11596        2017-09-26                 6    Male         Caucasian
# 1       37960        2015-01-02                 1  Female             Asian
# 2       81187        2021-07-08                 4    Male  African American
# 3       52559        2019-11-11                 2    Male  African American
# 4       88177        2015-12-06                 8    Male  African American
#
#                   Location  Fever Duration Symptoms Laboratory Tests  \
# 0  CityA, StateZ, Country2              25    Fever         Elevated
# 1  CityC, StateX, Country2               9     Rash         Elevated
# 2  CityB, StateZ, Country2               8    Fever         Elevated
# 3  CityA, StateY, Country1              19     Rash           Normal
# 4  CityB, StateY, Country3              28     Rash           Normal
#
#   Echocardiography Treatment Approach Clinical Outcomes  \
# 0           Normal            Aspirin         Worsening
# 1           Normal            Aspirin       Improvement
# 2           Normal            Aspirin       Improvement
# 3           Normal            Aspirin         Worsening
# 4           Normal            Aspirin            Stable
#
#               Complications Follow-up Visits Long-Term Effects
# 0               Myocarditis        Scheduled              Mild
# 1               Myocarditis    Not Scheduled              None
# 2               Myocarditis    Not Scheduled              None
# 3  Coronary Artery Aneurysm    Not Scheduled            Severe
# 4              Pericarditis        Scheduled              Mild

# %%
#Let's Print the Last 5 records of the dataset
df.tail()
# Out:
#        Patient ID Date of Diagnosis  Age at Diagnosis  Gender  Ethnicity  \
# 39995       17551        2014-06-13                18  Female   Hispanic
# 39996       80643        2018-11-06                14    Male  Caucasian
# 39997       90106        2017-02-12                12    Male      Asian
# 39998       58667        2023-06-21                16    Male  Caucasian
# 39999       13791        2017-02-11                18  Female      Other
#
#                       Location  Fever Duration             Symptoms  \
# 39995  CityA, StateX, Country2              23   Swollen Hands/Feet
# 39996  CityC, StateX, Country1              24                 Rash
# 39997  CityB, StateY, Country2              16  Swollen Lymph Nodes
# 39998  CityA, StateX, Country3              15             Red Eyes
# 39999  CityB, StateX, Country3               3                Fever
#
#       Laboratory Tests Echocardiography Treatment Approach Clinical Outcomes  \
# 39995         Elevated         Abnormal     IVIG + Aspirin         Worsening
# 39996           Normal         Abnormal               IVIG       Improvement
# 39997           Normal           Normal               IVIG       Improvement
# 39998           Normal         Abnormal            Aspirin       Improvement
# 39999         Elevated           Normal               IVIG         Worsening
#
#                   Complications Follow-up Visits Long-Term Effects
# 39995  Coronary Artery Aneurysm    Not Scheduled              None
# 39996  Coronary Artery Aneurysm    Not Scheduled              Mild
# 39997              Pericarditis    Not Scheduled              None
# 39998               Myocarditis    Not Scheduled              None
# 39999                      None    Not Scheduled              None

# %% [markdown]
# ### **Let's Understand More About the Data**

# %% [markdown]
# #### **Feature Description**

# %% [markdown]
# Patient ID: A unique identifier for each patient.
# Date of Diagnosis: The specific date when Kawasaki Disease was diagnosed.
# Age at Diagnosis: The age of the patient at the time of Kawasaki Disease diagnosis.
# Gender: The gender (male or female) of the patient.
# Ethnicity: The ethnicity or racial background of the patient.
# Location: The geographic location of the patient (city, state, country).
# Fever Duration: The duration of fever before diagnosis.
# Symptoms: A list of presenting symptoms such as rash, red eyes, swollen hands/feet, etc.
# Laboratory Tests: Results of relevant laboratory tests, such as elevated inflammatory markers.
# Echocardiography: Findings from echocardiographic assessments, crucial for assessing heart involvement.
# Treatment Approach: Details about the treatment strategy adopted, including IVIG, aspirin, etc.
# Clinical Outcomes: The progression of symptoms and overall health status after treatment.
# Complications: Any complications or adverse events associated with Kawasaki Disease.
# Follow-up Visits: Information about follow-up visits or assessments after initial treatment.
# Long-Term Effects: Data on any long-term effects or implications of Kawasaki Disease.

# %%
#Printing the shape of the dataset
df.shape
# Out:
# (40000, 15)

# %% [markdown]
# **Here we have 40000 observations with 15 features in our dataset**

# %%
#Getting the data types of all the columns
df.dtypes
# Out:
# Patient ID             int64
# Date of Diagnosis     object
# Age at Diagnosis       int64
# Gender                object
# Ethnicity             object
# Location              object
# Fever Duration         int64
# Symptoms              object
# Laboratory Tests      object
# Echocardiography      object
# Treatment Approach    object
# Clinical Outcomes     object
# Complications         object
# Follow-up Visits      object
# Long-Term Effects     object
# dtype: object

# %% [markdown]
# **Here in our dataset we have both object and float data types.**

# %%
#check details about the data set
print("Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :")
df.info()
# Out:
# Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Patient ID          40000 non-null  int64
#  1   Date of Diagnosis   40000 non-null  object
#  2   Age at Diagnosis    40000 non-null  int64
#  3   Gender              40000 non-null  object
#  4   Ethnicity           40000 non-null  object
#  5   Location            40000 non-null  object
#  6   Fever Duration      40000 non-null  int64
#  7   Symptoms            40000 non-null  object
#  8   Laboratory Tests    40000 non-null  object
#  9   Echocardiography    40000 non-null  object
#  10  Treatment Approach  40000 non-null  object
#  11  Clinical Outcomes   40000 non-null  object
#  12  Complications       40000 non-null  object
#  13  Follow-up Visits    40000 non-null  object
#  14  Long-Term Effects   40000 non-null  object
# dtypes: int64(3), object(12)
# memory usage: 4.6+ MB

# %%
#Here is the unique values in our data
print("The unique values in each and every column in our data are as below:")
df.nunique()
# Out:
# The unique values in each and every column in our data are as below:
# Patient ID            32239
# Date of Diagnosis      3649
# Age at Diagnosis         18
# Gender                    2
# Ethnicity                 5
# Location                 27
# Fever Duration           30
# Symptoms                  5
# Laboratory Tests          2
# Echocardiography          2
# Treatment Approach        3
# Clinical Outcomes         3
# Complications             4
# Follow-up Visits          2
# Long-Term Effects         3
# dtype: int64

# %%
print('The statistical information about our data set is as below :')
df.describe(include='all').T
# Out:
# The statistical information about our data set is as below :
#                       count unique                      top   freq  \
# Patient ID          40000.0    NaN                      NaN    NaN
# Date of Diagnosis     40000   3649               2017-08-05     23
# Age at Diagnosis    40000.0    NaN                      NaN    NaN
# Gender                40000      2                   Female  20012
# Ethnicity             40000      5                 Hispanic   8112
# Location              40000     27  CityB, StateY, Country3   1576
# Fever Duration      40000.0    NaN                      NaN    NaN
# Symptoms              40000      5       Swollen Hands/Feet   8076
# Laboratory Tests      40000      2                 Elevated  20110
# Echocardiography      40000      2                   Normal  20011
# Treatment Approach    40000      3                     IVIG  13404
# Clinical Outcomes     40000      3                   Stable  13512
# Complications         40000      4             Pericarditis  10157
# Follow-up Visits      40000      2            Not Scheduled  20061
# Long-Term Effects     40000      3                     None  13400
#
#                             mean           std      min      25%      50%  \
# Patient ID          54964.695275  26052.617579  10000.0  32383.0  54970.5
# Date of Diagnosis            NaN           NaN      NaN      NaN      NaN
# Age at Diagnosis        9.536075      5.209038      1.0      5.0     10.0
# Gender                       NaN           NaN      NaN      NaN      NaN
# Ethnicity                    NaN           NaN      NaN      NaN      NaN
# Location                     NaN           NaN      NaN      NaN      NaN
# Fever Duration         15.452125      8.651981      1.0      8.0     15.0
# Symptoms                     NaN           NaN      NaN      NaN      NaN
# Laboratory Tests             NaN           NaN      NaN      NaN      NaN
# Echocardiography             NaN           NaN      NaN      NaN      NaN
# Treatment Approach           NaN           NaN      NaN      NaN      NaN
# Clinical Outcomes            NaN           NaN      NaN      NaN      NaN
# Complications                NaN           NaN      NaN      NaN      NaN
# Follow-up Visits             NaN           NaN      NaN      NaN      NaN
# Long-Term Effects            NaN           NaN      NaN      NaN      NaN
#
#                          75%      max
# Patient ID          77496.25  99991.0
# Date of Diagnosis        NaN      NaN
# Age at Diagnosis        14.0     18.0
# Gender                   NaN      NaN
# Ethnicity                NaN      NaN
# Location                 NaN      NaN
# Fever Duration          23.0     30.0
# Symptoms                 NaN      NaN
# Laboratory Tests         NaN      NaN
# Echocardiography         NaN      NaN
# Treatment Approach       NaN      NaN
# Clinical Outcomes        NaN      NaN
# Complications            NaN      NaN
# Follow-up Visits         NaN      NaN
# Long-Term Effects        NaN      NaN

# %% [markdown]
# **The above table shows the statistical information about the each and every column of our data set.**

# %%
# Let's Check the duplicated values in our data
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **From the above we came to know that there is no duplicate values in our data set.**

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %%
#Let's check the null values present in the data set
df.isnull().sum()
# Out:
# Patient ID            0
# Date of Diagnosis     0
# Age at Diagnosis      0
# Gender                0
# Ethnicity             0
# Location              0
# Fever Duration        0
# Symptoms              0
# Laboratory Tests      0
# Echocardiography      0
# Treatment Approach    0
# Clinical Outcomes     0
# Complications         0
# Follow-up Visits      0
# Long-Term Effects     0
# dtype: int64

# %% [markdown]
# **From the above we found that there are some missing values in emp_title,emp_length,title, revol_util, mort_acc and Pub_rec_bankruptcies column**

# %% [markdown]
# # It creates a dataframe called 'missing' that calculates the percentage of missing values in each column of the 'df' dataset. It then plots a graph using seaborn library, displaying the percentage of missing values for each column as data points on the y-axis. The x-axis represents the column names. This graph helps visualize the extent of missing data in the dataset, allowing for easy identification of columns with high percentages of missing values.

# %%
#plot the graph to check wether there are any missing value present
missing = pd.DataFrame((df.isnull().sum())*100/df.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot(x='index',y=0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
# Checking Null Value by plotting Heatmap
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
print("Here are the columnn names of our data set :")
df.columns
# Out:
# Here are the columnn names of our data set :
# Index(['Patient ID', 'Date of Diagnosis', 'Age at Diagnosis', 'Gender',
#        'Ethnicity', 'Location', 'Fever Duration', 'Symptoms',
#        'Laboratory Tests', 'Echocardiography', 'Treatment Approach',
#        'Clinical Outcomes', 'Complications', 'Follow-up Visits',
#        'Long-Term Effects'],
#       dtype='object')

# %%
df
# Out:
#        Patient ID Date of Diagnosis  Age at Diagnosis  Gender  \
# 0           11596        2017-09-26                 6    Male
# 1           37960        2015-01-02                 1  Female
# 2           81187        2021-07-08                 4    Male
# 3           52559        2019-11-11                 2    Male
# 4           88177        2015-12-06                 8    Male
# ...           ...               ...               ...     ...
# 39995       17551        2014-06-13                18  Female
# 39996       80643        2018-11-06                14    Male
# 39997       90106        2017-02-12                12    Male
# 39998       58667        2023-06-21                16    Male
# 39999       13791        2017-02-11                18  Female
#
#               Ethnicity                 Location  Fever Duration  \
# 0             Caucasian  CityA, StateZ, Country2              25
# 1                 Asian  CityC, StateX, Country2               9
# 2      African American  CityB, StateZ, Country2               8
# 3      African American  CityA, StateY, Country1              19
# 4      African American  CityB, StateY, Country3              28
# ...                 ...                      ...             ...
# 39995          Hispanic  CityA, StateX, Country2              23
# 39996         Caucasian  CityC, StateX, Country1              24
# 39997             Asian  CityB, StateY, Country2              16
# 39998         Caucasian  CityA, StateX, Country3              15
# 39999             Other  CityB, StateX, Country3               3
#
#                   Symptoms Laboratory Tests Echocardiography  \
# 0                    Fever         Elevated           Normal
# 1                     Rash         Elevated           Normal
# 2                    Fever         Elevated           Normal
# 3                     Rash           Normal           Normal
# 4                     Rash           Normal           Normal
# ...                    ...              ...              ...
# 39995   Swollen Hands/Feet         Elevated         Abnormal
# 39996                 Rash           Normal         Abnormal
# 39997  Swollen Lymph Nodes           Normal           Normal
# 39998             Red Eyes           Normal         Abnormal
# 39999                Fever         Elevated           Normal
#
#       Treatment Approach Clinical Outcomes             Complications  \
# 0                Aspirin         Worsening               Myocarditis
# 1                Aspirin       Improvement               Myocarditis
# 2                Aspirin       Improvement               Myocarditis
# 3                Aspirin         Worsening  Coronary Artery Aneurysm
# 4                Aspirin            Stable              Pericarditis
# ...                  ...               ...                       ...
# 39995     IVIG + Aspirin         Worsening  Coronary Artery Aneurysm
# 39996               IVIG       Improvement  Coronary Artery Aneurysm
# 39997               IVIG       Improvement              Pericarditis
# 39998            Aspirin       Improvement               Myocarditis
# 39999               IVIG         Worsening                      None
#
#       Follow-up Visits Long-Term Effects
# 0            Scheduled              Mild
# 1        Not Scheduled              None
# 2        Not Scheduled              None
# 3        Not Scheduled            Severe
# 4            Scheduled              Mild
# ...                ...               ...
# 39995    Not Scheduled              None
# 39996    Not Scheduled              Mild
# 39997    Not Scheduled              None
# 39998    Not Scheduled              None
# 39999    Not Scheduled              None
#
# [40000 rows x 15 columns]

# %%
#  distribution plot for Patient ID column
sns.distplot(df['Patient ID'])
# Out:
# C:\Users\0420\AppData\Local\Temp\ipykernel_11872\1220908146.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Patient ID', ylabel='Density'>

# %%
#  distribution plot for Date of Diagnosis column
sns.distplot(df['Age at Diagnosis'])
# Out:
# C:\Users\0420\AppData\Local\Temp\ipykernel_11872\2481027775.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <Axes: xlabel='Age at Diagnosis', ylabel='Density'>

# %%
# generates a missing value matrix plot to visualize the presence of missing data in the DataFrame
msno.matrix(df)
plt.show()

# %% [markdown]
# It generates a bar chart using Seaborn, displaying the count of categories within the 'Ethnicity' column of a DataFrame, with rotated x-axis labels for improved readability.

# %%
# Create a bar chart
sns.countplot(data=df, x='Ethnicity')
plt.xlabel('Categories')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Rotate x-axis labels for readability
plt.show()

# %% [markdown]
# It creates a stacked bar chart that visualizes the relationship between two categorical variables, "Treatment Approach" and "Echocardiography," showing the count of each category within different treatment approaches.

# %%
# Create a stacked bar chart
sns.countplot(data=df, x='Treatment Approach', hue='Echocardiography')
# plt.title('Relationship between Two Categorical Variables')
plt.xlabel('Treatment Approach')
plt.ylabel('Count')
plt.legend(title='Treatment Approach', loc='upper right')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %%
df.dtypes
# Out:
# Patient ID             int64
# Date of Diagnosis     object
# Age at Diagnosis       int64
# Gender                object
# Ethnicity             object
# Location              object
# Fever Duration         int64
# Symptoms              object
# Laboratory Tests      object
# Echocardiography      object
# Treatment Approach    object
# Clinical Outcomes     object
# Complications         object
# Follow-up Visits      object
# Long-Term Effects     object
# dtype: object

# %%
print("After the null value imputation the number of missing value count is :")
df.isnull().sum()
# Out:
# After the null value imputation the number of missing value count is :
# Patient ID            0
# Date of Diagnosis     0
# Age at Diagnosis      0
# Gender                0
# Ethnicity             0
# Location              0
# Fever Duration        0
# Symptoms              0
# Laboratory Tests      0
# Echocardiography      0
# Treatment Approach    0
# Clinical Outcomes     0
# Complications         0
# Follow-up Visits      0
# Long-Term Effects     0
# dtype: int64

# %% [markdown]
# #### **Labelencoding of Categorical Features**

# %%
df.shape
# Out:
# (40000, 15)

# %%
df.columns
# Out:
# Index(['Patient ID', 'Date of Diagnosis', 'Age at Diagnosis', 'Gender',
#        'Ethnicity', 'Location', 'Fever Duration', 'Symptoms',
#        'Laboratory Tests', 'Echocardiography', 'Treatment Approach',
#        'Clinical Outcomes', 'Complications', 'Follow-up Visits',
#        'Long-Term Effects'],
#       dtype='object')

# %% [markdown]
# The 'drop' method in pandas is used to remove specific columns or rows from a DataFrame. It allows for data manipulation by excluding the specified data, either in-place or by creating a new DataFrame without the dropped elements.

# %%
# removes the 'Patient ID' column from the DataFrame 'df' and makes this change in-place.
df.drop('Patient ID',axis=1 , inplace=True)

# %%
# removes the 'Date of Diagnosis' column from the DataFrame 'df' and makes this change in-place.
df.drop('Date of Diagnosis',axis=1 , inplace=True)

# %%
#Printing the shape of the dataset
df.shape
# Out:
# (40000, 13)

# %%
df
# Out:
#        Age at Diagnosis  Gender         Ethnicity                 Location  \
# 0                     6    Male         Caucasian  CityA, StateZ, Country2
# 1                     1  Female             Asian  CityC, StateX, Country2
# 2                     4    Male  African American  CityB, StateZ, Country2
# 3                     2    Male  African American  CityA, StateY, Country1
# 4                     8    Male  African American  CityB, StateY, Country3
# ...                 ...     ...               ...                      ...
# 39995                18  Female          Hispanic  CityA, StateX, Country2
# 39996                14    Male         Caucasian  CityC, StateX, Country1
# 39997                12    Male             Asian  CityB, StateY, Country2
# 39998                16    Male         Caucasian  CityA, StateX, Country3
# 39999                18  Female             Other  CityB, StateX, Country3
#
#        Fever Duration             Symptoms Laboratory Tests Echocardiography  \
# 0                  25                Fever         Elevated           Normal
# 1                   9                 Rash         Elevated           Normal
# 2                   8                Fever         Elevated           Normal
# 3                  19                 Rash           Normal           Normal
# 4                  28                 Rash           Normal           Normal
# ...               ...                  ...              ...              ...
# 39995              23   Swollen Hands/Feet         Elevated         Abnormal
# 39996              24                 Rash           Normal         Abnormal
# 39997              16  Swollen Lymph Nodes           Normal           Normal
# 39998              15             Red Eyes           Normal         Abnormal
# 39999               3                Fever         Elevated           Normal
#
#       Treatment Approach Clinical Outcomes             Complications  \
# 0                Aspirin         Worsening               Myocarditis
# 1                Aspirin       Improvement               Myocarditis
# 2                Aspirin       Improvement               Myocarditis
# 3                Aspirin         Worsening  Coronary Artery Aneurysm
# 4                Aspirin            Stable              Pericarditis
# ...                  ...               ...                       ...
# 39995     IVIG + Aspirin         Worsening  Coronary Artery Aneurysm
# 39996               IVIG       Improvement  Coronary Artery Aneurysm
# 39997               IVIG       Improvement              Pericarditis
# 39998            Aspirin       Improvement               Myocarditis
# 39999               IVIG         Worsening                      None
#
#       Follow-up Visits Long-Term Effects
# 0            Scheduled              Mild
# 1        Not Scheduled              None
# 2        Not Scheduled              None
# 3        Not Scheduled            Severe
# 4            Scheduled              Mild
# ...                ...               ...
# 39995    Not Scheduled              None
# 39996    Not Scheduled              Mild
# 39997    Not Scheduled              None
# 39998    Not Scheduled              None
# 39999    Not Scheduled              None
#
# [40000 rows x 13 columns]

# %% [markdown]
# It creates a pie chart to visualize the gender distribution in a DataFrame, highlighting the "Male" category with a slight explosion effect.

# %%
plt.figure(figsize=(7,7))
size=df['Gender'].value_counts()
label=['Female','Male']
color=['Pink','Blue']
explode=[0,0.1]
plt.pie(size,explode=explode,labels=label,colors=color,shadow=True)
plt.legend()
plt.show()

# %% [markdown]
# LabelEncoder is a preprocessing technique used in machine learning to convert categorical labels into numerical values, allowing algorithms to work with categorical data by assigning a unique integer to each category.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df['Ethnicity'] = le.fit_transform(df['Ethnicity'])
df['Location'] = le.fit_transform(df['Location'])
df['Symptoms'] = le.fit_transform(df['Symptoms'])
df['Laboratory Tests'] = le.fit_transform(df['Laboratory Tests'])
df['Echocardiography'] = le.fit_transform(df['Echocardiography'])
df['Treatment Approach'] = le.fit_transform(df['Treatment Approach'])
df['Clinical Outcomes'] = le.fit_transform(df['Clinical Outcomes'])
df['Complications'] = le.fit_transform(df['Complications'])
df['Follow-up Visits'] = le.fit_transform(df['Follow-up Visits'])
df['Long-Term Effects'] = le.fit_transform(df['Long-Term Effects'])

# %%
df.head()
# Out:
#    Age at Diagnosis  Gender  Ethnicity  Location  Fever Duration  Symptoms  \
# 0                 6       1          2         7              25         0
# 1                 1       0          1        19               9         1
# 2                 4       1          0        16               8         0
# 3                 2       1          0         3              19         1
# 4                 8       1          0        14              28         1
#
#    Laboratory Tests  Echocardiography  Treatment Approach  Clinical Outcomes  \
# 0                 0                 1                   0                  2
# 1                 0                 1                   0                  0
# 2                 0                 1                   0                  0
# 3                 1                 1                   0                  2
# 4                 1                 1                   0                  1
#
#    Complications  Follow-up Visits  Long-Term Effects
# 0              1                 1                  0
# 1              1                 0                  1
# 2              1                 0                  1
# 3              0                 0                  2
# 4              3                 1                  0

# %%
#Getting the data types of all the columns
df.dtypes
# Out:
# Age at Diagnosis      int64
# Gender                int32
# Ethnicity             int32
# Location              int32
# Fever Duration        int64
# Symptoms              int32
# Laboratory Tests      int32
# Echocardiography      int32
# Treatment Approach    int32
# Clinical Outcomes     int32
# Complications         int32
# Follow-up Visits      int32
# Long-Term Effects     int32
# dtype: object

# %% [markdown]
# **Here after applying the Label Encoder all the categorical columns has been converted into numeric.**

# %%
#check details about the data set
print("Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :")
df.info()
# Out:
# Here is the information about our data set which includes the number of columns, number of rows, data types , null counts and the memory size as well :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age at Diagnosis    40000 non-null  int64
#  1   Gender              40000 non-null  int32
#  2   Ethnicity           40000 non-null  int32
#  3   Location            40000 non-null  int32
#  4   Fever Duration      40000 non-null  int64
#  5   Symptoms            40000 non-null  int32
#  6   Laboratory Tests    40000 non-null  int32
#  7   Echocardiography    40000 non-null  int32
#  8   Treatment Approach  40000 non-null  int32
#  9   Clinical Outcomes   40000 non-null  int32
#  10  Complications       40000 non-null  int32
#  11  Follow-up Visits    40000 non-null  int32
#  12  Long-Term Effects   40000 non-null  int32
# dtypes: int32(11), int64(2)
# memory usage: 2.3 MB

# %% [markdown]
# #### **Feature Selection**

# %% [markdown]
# Let's plot the correlation plot to select the features

# %% [markdown]
# A correlation matrix is a square table that displays the correlation coefficients between many variables. It is used to understand how variables are related to each other. In a correlation matrix, each cell represents the correlation between two variables, typically ranging from -1 (perfect negative correlation) to 1 (perfect positive correlation), with 0 indicating no correlation. Positive values suggest that variables tend to increase together, while negative values indicate that one tends to decrease as the other increases. It's a valuable tool for data analysis, helping to identify relationships, dependencies, and potential multicollinearity among variables in datasets.

# %%
## plot the Correlation matrix
plt.figure(figsize=(17,8))
correlation=df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Let's save the correlation value in csv format

# %%
corr = df.corr()

# %%
corr
# Out:
#                     Age at Diagnosis    Gender  Ethnicity  Location  \
# Age at Diagnosis            1.000000 -0.000385   0.000967 -0.000728
# Gender                     -0.000385  1.000000  -0.005158 -0.009205
# Ethnicity                   0.000967 -0.005158   1.000000 -0.001055
# Location                   -0.000728 -0.009205  -0.001055  1.000000
# Fever Duration              0.000799 -0.002809   0.007357  0.004598
# Symptoms                   -0.003226  0.001764  -0.000874 -0.000521
# Laboratory Tests            0.007732 -0.005803   0.005595 -0.002531
# Echocardiography           -0.009977  0.004350   0.000903 -0.010677
# Treatment Approach         -0.001137  0.006498  -0.005171 -0.007390
# Clinical Outcomes          -0.002658 -0.002706   0.008482  0.002648
# Complications               0.002189  0.002702   0.000154  0.010191
# Follow-up Visits            0.004849 -0.002552   0.002257 -0.004211
# Long-Term Effects           0.001636 -0.007783   0.002947  0.003365
#
#                     Fever Duration  Symptoms  Laboratory Tests  \
# Age at Diagnosis          0.000799 -0.003226          0.007732
# Gender                   -0.002809  0.001764         -0.005803
# Ethnicity                 0.007357 -0.000874          0.005595
# Location                  0.004598 -0.000521         -0.002531
# Fever Duration            1.000000  0.004572         -0.004119
# Symptoms                  0.004572  1.000000         -0.004598
# Laboratory Tests         -0.004119 -0.004598          1.000000
# Echocardiography          0.004892  0.006603          0.002453
# Treatment Approach        0.000082 -0.000978         -0.001853
# Clinical Outcomes         0.008250  0.001187          0.005633
# Complications             0.001797 -0.002177         -0.001499
# Follow-up Visits          0.004098 -0.008972         -0.000767
# Long-Term Effects         0.007797 -0.002610         -0.004443
#
#                     Echocardiography  Treatment Approach  Clinical Outcomes  \
# Age at Diagnosis           -0.009977           -0.001137          -0.002658
# Gender                      0.004350            0.006498          -0.002706
# Ethnicity                   0.000903           -0.005171           0.008482
# Location                   -0.010677           -0.007390           0.002648
# Fever Duration              0.004892            0.000082           0.008250
# Symptoms                    0.006603           -0.000978           0.001187
# Laboratory Tests            0.002453           -0.001853           0.005633
# Echocardiography            1.000000           -0.008706           0.000063
# Treatment Approach         -0.008706            1.000000          -0.003287
# Clinical Outcomes           0.000063           -0.003287           1.000000
# Complications              -0.000227            0.000673           0.002902
# Follow-up Visits           -0.003798           -0.005035          -0.002100
# Long-Term Effects           0.004595            0.000127           0.005899
#
#                     Complications  Follow-up Visits  Long-Term Effects
# Age at Diagnosis         0.002189          0.004849           0.001636
# Gender                   0.002702         -0.002552          -0.007783
# Ethnicity                0.000154          0.002257           0.002947
# Location                 0.010191         -0.004211           0.003365
# Fever Duration           0.001797          0.004098           0.007797
# Symptoms                -0.002177         -0.008972          -0.002610
# Laboratory Tests        -0.001499         -0.000767          -0.004443
# Echocardiography        -0.000227         -0.003798           0.004595
# Treatment Approach       0.000673         -0.005035           0.000127
# Clinical Outcomes        0.002902         -0.002100           0.005899
# Complications            1.000000         -0.001717           0.000559
# Follow-up Visits        -0.001717          1.000000          -0.009731
# Long-Term Effects        0.000559         -0.009731           1.000000

# %%
# corr.to_csv('correlation.csv')

# %%
import numpy as np

# Create correlation matrix
corr_matrix = df.corr().abs()

# %%
corr_matrix
# Out:
#                     Age at Diagnosis    Gender  Ethnicity  Location  \
# Age at Diagnosis            1.000000  0.000385   0.000967  0.000728
# Gender                      0.000385  1.000000   0.005158  0.009205
# Ethnicity                   0.000967  0.005158   1.000000  0.001055
# Location                    0.000728  0.009205   0.001055  1.000000
# Fever Duration              0.000799  0.002809   0.007357  0.004598
# Symptoms                    0.003226  0.001764   0.000874  0.000521
# Laboratory Tests            0.007732  0.005803   0.005595  0.002531
# Echocardiography            0.009977  0.004350   0.000903  0.010677
# Treatment Approach          0.001137  0.006498   0.005171  0.007390
# Clinical Outcomes           0.002658  0.002706   0.008482  0.002648
# Complications               0.002189  0.002702   0.000154  0.010191
# Follow-up Visits            0.004849  0.002552   0.002257  0.004211
# Long-Term Effects           0.001636  0.007783   0.002947  0.003365
#
#                     Fever Duration  Symptoms  Laboratory Tests  \
# Age at Diagnosis          0.000799  0.003226          0.007732
# Gender                    0.002809  0.001764          0.005803
# Ethnicity                 0.007357  0.000874          0.005595
# Location                  0.004598  0.000521          0.002531
# Fever Duration            1.000000  0.004572          0.004119
# Symptoms                  0.004572  1.000000          0.004598
# Laboratory Tests          0.004119  0.004598          1.000000
# Echocardiography          0.004892  0.006603          0.002453
# Treatment Approach        0.000082  0.000978          0.001853
# Clinical Outcomes         0.008250  0.001187          0.005633
# Complications             0.001797  0.002177          0.001499
# Follow-up Visits          0.004098  0.008972          0.000767
# Long-Term Effects         0.007797  0.002610          0.004443
#
#                     Echocardiography  Treatment Approach  Clinical Outcomes  \
# Age at Diagnosis            0.009977            0.001137           0.002658
# Gender                      0.004350            0.006498           0.002706
# Ethnicity                   0.000903            0.005171           0.008482
# Location                    0.010677            0.007390           0.002648
# Fever Duration              0.004892            0.000082           0.008250
# Symptoms                    0.006603            0.000978           0.001187
# Laboratory Tests            0.002453            0.001853           0.005633
# Echocardiography            1.000000            0.008706           0.000063
# Treatment Approach          0.008706            1.000000           0.003287
# Clinical Outcomes           0.000063            0.003287           1.000000
# Complications               0.000227            0.000673           0.002902
# Follow-up Visits            0.003798            0.005035           0.002100
# Long-Term Effects           0.004595            0.000127           0.005899
#
#                     Complications  Follow-up Visits  Long-Term Effects
# Age at Diagnosis         0.002189          0.004849           0.001636
# Gender                   0.002702          0.002552           0.007783
# Ethnicity                0.000154          0.002257           0.002947
# Location                 0.010191          0.004211           0.003365
# Fever Duration           0.001797          0.004098           0.007797
# Symptoms                 0.002177          0.008972           0.002610
# Laboratory Tests         0.001499          0.000767           0.004443
# Echocardiography         0.000227          0.003798           0.004595
# Treatment Approach       0.000673          0.005035           0.000127
# Clinical Outcomes        0.002902          0.002100           0.005899
# Complications            1.000000          0.001717           0.000559
# Follow-up Visits         0.001717          1.000000           0.009731
# Long-Term Effects        0.000559          0.009731           1.000000

# %%
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
# C:\Users\0420\AppData\Local\Temp\ipykernel_11872\2797590206.py:2: DeprecationWarning:
#
# `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#                     Age at Diagnosis    Gender  Ethnicity  Location  \
# Age at Diagnosis                 NaN  0.000385   0.000967  0.000728
# Gender                           NaN       NaN   0.005158  0.009205
# Ethnicity                        NaN       NaN        NaN  0.001055
# Location                         NaN       NaN        NaN       NaN
# Fever Duration                   NaN       NaN        NaN       NaN
# Symptoms                         NaN       NaN        NaN       NaN
# Laboratory Tests                 NaN       NaN        NaN       NaN
# Echocardiography                 NaN       NaN        NaN       NaN
# Treatment Approach               NaN       NaN        NaN       NaN
# Clinical Outcomes                NaN       NaN        NaN       NaN
# Complications                    NaN       NaN        NaN       NaN
# Follow-up Visits                 NaN       NaN        NaN       NaN
# Long-Term Effects                NaN       NaN        NaN       NaN
#
#                     Fever Duration  Symptoms  Laboratory Tests  \
# Age at Diagnosis          0.000799  0.003226          0.007732
# Gender                    0.002809  0.001764          0.005803
# Ethnicity                 0.007357  0.000874          0.005595
# Location                  0.004598  0.000521          0.002531
# Fever Duration                 NaN  0.004572          0.004119
# Symptoms                       NaN       NaN          0.004598
# Laboratory Tests               NaN       NaN               NaN
# Echocardiography               NaN       NaN               NaN
# Treatment Approach             NaN       NaN               NaN
# Clinical Outcomes              NaN       NaN               NaN
# Complications                  NaN       NaN               NaN
# Follow-up Visits               NaN       NaN               NaN
# Long-Term Effects              NaN       NaN               NaN
#
#                     Echocardiography  Treatment Approach  Clinical Outcomes  \
# Age at Diagnosis            0.009977            0.001137           0.002658
# Gender                      0.004350            0.006498           0.002706
# Ethnicity                   0.000903            0.005171           0.008482
# Location                    0.010677            0.007390           0.002648
# Fever Duration              0.004892            0.000082           0.008250
# Symptoms                    0.006603            0.000978           0.001187
# Laboratory Tests            0.002453            0.001853           0.005633
# Echocardiography                 NaN            0.008706           0.000063
# Treatment Approach               NaN                 NaN           0.003287
# Clinical Outcomes                NaN                 NaN                NaN
# Complications                    NaN                 NaN                NaN
# Follow-up Visits                 NaN                 NaN                NaN
# Long-Term Effects                NaN                 NaN                NaN
#
#                     Complications  Follow-up Visits  Long-Term Effects
# Age at Diagnosis         0.002189          0.004849           0.001636
# Gender                   0.002702          0.002552           0.007783
# Ethnicity                0.000154          0.002257           0.002947
# Location                 0.010191          0.004211           0.003365
# Fever Duration           0.001797          0.004098           0.007797
# Symptoms                 0.002177          0.008972           0.002610
# Laboratory Tests         0.001499          0.000767           0.004443
# Echocardiography         0.000227          0.003798           0.004595
# Treatment Approach       0.000673          0.005035           0.000127
# Clinical Outcomes        0.002902          0.002100           0.005899
# Complications                 NaN          0.001717           0.000559
# Follow-up Visits              NaN               NaN           0.009731
# Long-Term Effects             NaN               NaN                NaN

# %%
# Univariate Analysis
#Printing boxplot for each numerical column present in the data set
df1=df.select_dtypes(exclude=['object','bool'])
for column in df1:
        plt.figure(figsize=(17,1))
        sns.boxplot(data=df1, x=column)
plt.show()

# %%
#Printing displot for each numerical column present in the data set
df1=df.select_dtypes(exclude=['object','bool'])
for column in df1:
        plt.figure(figsize=(17,1))
        sns.displot(data=df1, x=column)
plt.show()
# Out:
# C:\Users\0420\AppData\Local\Temp\ipykernel_11872\1747525221.py:4: RuntimeWarning:
#
# More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.

# %%
#Printing strip plot for each numerical column present in the data set
df1=df.select_dtypes(exclude=['object','bool'])
for column in df1:
        plt.figure(figsize=(17,1))
        sns.stripplot(data=df1, x=column)
plt.show()

# %%
df.hist(figsize = (14,12)) #shows graphically the value counts of each column
# Out:
# array([[<Axes: title={'center': 'Age at Diagnosis'}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'Ethnicity'}>,
#         <Axes: title={'center': 'Location'}>],
#        [<Axes: title={'center': 'Fever Duration'}>,
#         <Axes: title={'center': 'Symptoms'}>,
#         <Axes: title={'center': 'Laboratory Tests'}>,
#         <Axes: title={'center': 'Echocardiography'}>],
#        [<Axes: title={'center': 'Treatment Approach'}>,
#         <Axes: title={'center': 'Clinical Outcomes'}>,
#         <Axes: title={'center': 'Complications'}>,
#         <Axes: title={'center': 'Follow-up Visits'}>],
#        [<Axes: title={'center': 'Long-Term Effects'}>, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# A box plot, also known as a box-and-whisker plot, is a graphical representation that displays the distribution, central tendency (median), and spread (interquartile range) of a dataset, making it easy to identify outliers and understand the data's overall variability.

# %%
#box plot
plt.figure(figsize=(20,20))
ax = sns.boxplot(data=df)

# %%
df.head()
# Out:
#    Age at Diagnosis  Gender  Ethnicity  Location  Fever Duration  Symptoms  \
# 0                 6       1          2         7              25         0
# 1                 1       0          1        19               9         1
# 2                 4       1          0        16               8         0
# 3                 2       1          0         3              19         1
# 4                 8       1          0        14              28         1
#
#    Laboratory Tests  Echocardiography  Treatment Approach  Clinical Outcomes  \
# 0                 0                 1                   0                  2
# 1                 0                 1                   0                  0
# 2                 0                 1                   0                  0
# 3                 1                 1                   0                  2
# 4                 1                 1                   0                  1
#
#    Complications  Follow-up Visits  Long-Term Effects
# 0              1                 1                  0
# 1              1                 0                  1
# 2              1                 0                  1
# 3              0                 0                  2
# 4              3                 1                  0

# %% [markdown]
# # **Model Building**

# %% [markdown]
# #### **K-Means Clustering**

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
X = df

# %%
X
# Out:
#        Age at Diagnosis  Gender  Ethnicity  Location  Fever Duration  \
# 0                     6       1          2         7              25
# 1                     1       0          1        19               9
# 2                     4       1          0        16               8
# 3                     2       1          0         3              19
# 4                     8       1          0        14              28
# ...                 ...     ...        ...       ...             ...
# 39995                18       0          3         1              23
# 39996                14       1          2        18              24
# 39997                12       1          1        13              16
# 39998                16       1          2         2              15
# 39999                18       0          4        11               3
#
#        Symptoms  Laboratory Tests  Echocardiography  Treatment Approach  \
# 0             0                 0                 1                   0
# 1             1                 0                 1                   0
# 2             0                 0                 1                   0
# 3             1                 1                 1                   0
# 4             1                 1                 1                   0
# ...         ...               ...               ...                 ...
# 39995         3                 0                 0                   2
# 39996         1                 1                 0                   1
# 39997         4                 1                 1                   1
# 39998         2                 1                 0                   0
# 39999         0                 0                 1                   1
#
#        Clinical Outcomes  Complications  Follow-up Visits  Long-Term Effects
# 0                      2              1                 1                  0
# 1                      0              1                 0                  1
# 2                      0              1                 0                  1
# 3                      2              0                 0                  2
# 4                      1              3                 1                  0
# ...                  ...            ...               ...                ...
# 39995                  2              0                 0                  1
# 39996                  0              0                 0                  0
# 39997                  0              3                 0                  1
# 39998                  0              1                 0                  1
# 39999                  2              2                 0                  1
#
# [40000 rows x 13 columns]

# %%
from sklearn.metrics import silhouette_score

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Assuming you have your data stored in the 'X' variable

# Determine the optimal number of clusters (k) using the elbow method
twss = []
silhouette_scores = []
k_range = range(2, 9)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    twss.append(kmeans.inertia_)
    labels = kmeans.labels_
    silhouette_scores.append(silhouette_score(X, labels))
# Out:
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# c:\Program Files\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning

# %%
# Plot the Elbow Method graph to find the optimal k
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(k_range, twss, marker='o', linestyle='-', color='b')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Total Within-Cluster Sum of Squares (TWSS)')
plt.title('Elbow Method for Optimal k')

plt.subplot(1, 2, 2)
plt.plot(k_range, silhouette_scores, marker='o', linestyle='-', color='g')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Optimal k')

plt.tight_layout()
plt.show()

# %%
# print("TWSS:", TWSS)
print("Silhouette Scores:", silhouette_scores)
# Out:
# Silhouette Scores: [0.2907699980137768, 0.27322298358888636, 0.27159565269614266, 0.254214212936171, 0.24178244859474135, 0.22635925857077427, 0.22050316362212874]

# %% [markdown]
# <h1>GaussianMixture</h1>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture


optimal_n_clusters = 4
data_preprocessed = X

gmm = GaussianMixture(n_components=optimal_n_clusters+2, random_state=0)
gmm.fit(data_preprocessed)

# Predict the cluster assignments for each data point
cluster_assignments = gmm.predict(data_preprocessed)

# Calculate the silhouette score
silhouette_avg = silhouette_score(data_preprocessed, cluster_assignments)
print(f'Silhouette Score: {silhouette_avg}')

#
# Out:
# Silhouette Score: 0.21513242274354552

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

optimal_n_clusters = 4
data_preprocessed = X  # Assuming data_preprocessed is a pandas DataFrame

# Create a Gaussian Mixture Model with a specified number of components (optimal_n_clusters + 2)
gmm = GaussianMixture(n_components=optimal_n_clusters, random_state=0)
gmm.fit(data_preprocessed)

# Predict the cluster assignments for each data point
cluster_assignments = gmm.predict(data_preprocessed)

# Calculate the silhouette score
silhouette_avg = silhouette_score(data_preprocessed, cluster_assignments)
print(f'Silhouette Score: {silhouette_avg:.2f}')

# Define custom colors for clusters
custom_colors = ['red', 'green', 'blue', 'purple']  # Add more colors if needed

# Plot the data points with custom cluster colors
plt.figure(figsize=(10, 7))
cluster_colors = [custom_colors[label] for label in cluster_assignments]
plt.scatter(data_preprocessed['Age at Diagnosis'], data_preprocessed['Fever Duration'], marker='.', s=50, lw=0, alpha=0.7, c=cluster_colors, edgecolor='k')

# Set plot labels and title
plt.xlabel('Age at Diagnosis')
plt.ylabel('Fever Duration')
plt.title(f'GMM Clustering with {optimal_n_clusters} Clusters (Silhouette Score: {silhouette_avg:.2f})')

# Show the plot
plt.show()
# Out:
# Silhouette Score: 0.27

# %% [markdown]
# <h1>DBSCAN</h1>

# %%
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
# Generate sample data
centers = [[1, 1], [-1, -1], [1, -1]]
X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)

X = StandardScaler().fit_transform(X)

# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=10).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_



# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels))

# Plot result
import matplotlib.pyplot as plt
# %matplotlib inline

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='k', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 3
# Estimated number of noise points: 18
# Homogeneity: 0.953
# Completeness: 0.883
# V-measure: 0.917
# Adjusted Rand Index: 0.952
# Adjusted Mutual Information: 0.916
# Silhouette Coefficient: 0.626

# %%
print("Silhouette Score for DBSCAN: %0.2f" % metrics.silhouette_score(X, labels))
# Out:
# Silhouette Score for DBSCAN: 0.63

# %%
A = df
print(A.shape)
# Out:
# (40000, 13)

# %% [markdown]
# ## Hierarchy cluster

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import silhouette_score, davies_bouldin_score

# Assuming you have a DataFrame named df with your data
# Example data (replace this with your own data)
data = X
df = pd.DataFrame(data)

# Perform hierarchical clustering
n_clusters = 2  # Number of clusters
clustering = AgglomerativeClustering(n_clusters=n_clusters)
cluster_labels = clustering.fit_predict(df)

# Calculate linkage matrix and plot the dendrogram
linkage_matrix = linkage(df, method='ward')
plt.figure(figsize=(12, 6))
dendrogram(linkage_matrix, orientation='top', labels=cluster_labels, distance_sort='descending', show_leaf_counts=True)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# Calculate silhouette score and Davies-Bouldin index
silhouette_avg = silhouette_score(df, cluster_labels)
davies_bouldin = davies_bouldin_score(df, cluster_labels)

print(f'Silhouette Score: {silhouette_avg:.2f}')
print(f'Davies-Bouldin Index: {davies_bouldin:.2f}')
# Out:
# Silhouette Score: 0.52
# Davies-Bouldin Index: 0.70
